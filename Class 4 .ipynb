# %%
import pandas as pd

# %%
import numpy as np

# %%
data={'state':['Ohio','Ohio','Ohio','Nevada','Nevada'], 'year':[2000,2001,2002,2002,2003], 'pop':[1.5,1.7,3.6,2.4,2.9]}
frame=pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2002  2.4
# 4  Nevada  2003  2.9

# %%
frame=pd.DataFrame(data, columns=['year', 'state', 'pop', 'Debt'], index = ['one','two','three','four','five'])

# %%
frame
# Out:
#        year   state  pop Debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2002  Nevada  2.4  NaN
# five   2003  Nevada  2.9  NaN

# %%
frame.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five'], dtype='object')

# %%
frame.loc['one']
# Out:
# year     2000
# state    Ohio
# pop       1.5
# Debt      NaN
# Name: one, dtype: object

# %%
frame.columns
# Out:
# Index(['year', 'state', 'pop', 'Debt'], dtype='object')

# %%
val=pd.Series([-1.2,-1.5,-1.7], index['two','four','five'])
val
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6c3bbd9a7cca> in <module>
# ----> 1 val=pd.Series([-1.2,-1.5,-1.7], index['two','four','five'])
#       2 val
#
# NameError: name 'index' is not defined

# %%
val=pd.Series([-1.2,-1.5,-1.7], index=['two','four','five'])
val
# Out:
# two    -1.2
# four   -1.5
# five   -1.7
# dtype: float64

# %%
pop = {'Nevada':{2001: 2.4, 2002: 2.9}, 'Ohio': {2000:1.5, 2001:1.7, 2002:3.6}}

# %%
frame3=pd.DataFrame(pop)

# %%
frame3
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6

# %%
pd.DataFrame(pop, index=[2001,2002,2003])
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2003     NaN   NaN

# %%
pdata = {'Ohio':frame3['Ohio'][:-1],'Nevada':frame3['Nevada'][:2]}

# %%
pdata
# Out:
# {'Ohio': 2000    1.5
#  2001    1.7
#  Name: Ohio, dtype: float64, 'Nevada': 2000    NaN
#  2001    2.4
#  Name: Nevada, dtype: float64}

# %%
pdata=pd.DataFrame(pdata)
pdata
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4

# %%
frame3.index.name= 'year'; frame3.columns.name = 'state'

# %%
frame3
# Out:
# state  Nevada  Ohio
# year
# 2000      NaN   1.5
# 2001      2.4   1.7
# 2002      2.9   3.6

# %%
frame3.values
# Out:
# array([[nan, 1.5],
#        [2.4, 1.7],
#        [2.9, 3.6]])

# %% [markdown]
# # Reindexing

# %%
obj=pd.Series([4.5,7.2,-5.3,3.6], index=['d','b','a','c'])

# %%
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2=obj.reindex(['a','b', 'c','d','e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3=pd.Series(['blue','purple','yellow'],index=[0,2,4])

# %%
obj3.reindex(range(6))
# Out:
# 0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4    yellow
# 5       NaN
# dtype: object

# %%
obj3.reindex(range(6), method='bfill')
# Out:
# 0      blue
# 1    purple
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object

# %%
obj3.reindex(range(6), method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame
# Out:
#        year   state  pop Debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2002  Nevada  2.4  NaN
# five   2003  Nevada  2.9  NaN

# %% [markdown]
#  # Reindexing on Frame

# %%
frame=pd.DataFrame(np.arange(9).reshape((3,3)),index=['a','c','d'], columns=['Ohio','Texas','California'])
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
frame2=frame.reindex(index=['f','b','a','d','c','g'], columns=['Texas','NewYork','Utah','California'])

# %%
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    NaN      NaN   NaN         NaN
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
states = ['Texas', 'Utah', 'California']
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
frame.reindex(index=['f','b','a','d','c','g'], columns=['Texas', 'Newyork','Utah','California','Bay'])
# Out:
#    Texas  Newyork  Utah  California  Bay
# f    NaN      NaN   NaN         NaN  NaN
# b    NaN      NaN   NaN         NaN  NaN
# a    1.0      NaN   NaN         2.0  NaN
# d    7.0      NaN   NaN         8.0  NaN
# c    4.0      NaN   NaN         5.0  NaN
# g    NaN      NaN   NaN         NaN  NaN

# %%
data=pd.DataFrame(np.arange(1,101).reshape((20,5)), columns=['a','b','c','d','e'],index=range(1,101,5))
data
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
list('abcde')
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
list('Ohio')
# Out:
# ['O', 'h', 'i', 'o']

# %%
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    NaN      NaN   NaN         NaN
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame2.loc['b']['California']
# Out:
# nan

# %%
frame2.loc['b'][2]
# Out:
# nan

# %%
frame2.loc

# %%
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    NaN      NaN   NaN         NaN
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame2.loc[::-1]
# Out:
#    Texas  NewYork  Utah  California
# g    NaN      NaN   NaN         NaN
# c    4.0      NaN   NaN         5.0
# d    7.0      NaN   NaN         8.0
# a    1.0      NaN   NaN         2.0
# b    NaN      NaN   NaN         NaN
# f    NaN      NaN   NaN         NaN

# %%
frame2.loc[::-1,::-1]
# Out:
#    California  Utah  NewYork  Texas
# g         NaN   NaN      NaN    NaN
# c         5.0   NaN      NaN    4.0
# d         8.0   NaN      NaN    7.0
# a         2.0   NaN      NaN    1.0
# b         NaN   NaN      NaN    NaN
# f         NaN   NaN      NaN    NaN

# %%
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    NaN      NaN   NaN         NaN
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame.loc['a':'c']
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5

# %%
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    NaN      NaN   NaN         NaN
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame2.iloc[1:3]
# Out:
#    Texas  NewYork  Utah  California
# b    NaN      NaN   NaN         NaN
# a    1.0      NaN   NaN         2.0

# %%
frame2.loc['b']['California']=2

# %%
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    NaN      NaN   NaN         2.0
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame2.loc['b'][0:2]=[4,6]
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    4.0      6.0   NaN         2.0
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame2.loc['b'][[0,2]]=[4,6]
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    4.0      6.0   6.0         2.0
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame2.loc['b']
# Out:
# Texas         4.0
# NewYork       6.0
# Utah          6.0
# California    2.0
# Name: b, dtype: float64

# %%
frame2.loc['b'][[2,0]]=frame2.loc['b'][[0,2]]
frame2
# Out:
#    Texas  NewYork  Utah  California
# f    NaN      NaN   NaN         NaN
# b    6.0      6.0   4.0         2.0
# a    1.0      NaN   NaN         2.0
# d    7.0      NaN   NaN         8.0
# c    4.0      NaN   NaN         5.0
# g    NaN      NaN   NaN         NaN

# %%
frame4=frame2.copy()
frame4['std']=[4,5,6,8,6,8]
frame4
# Out:
#    Texas  NewYork  Utah  California  std
# f    NaN      NaN   NaN         NaN    4
# b    6.0      6.0   4.0         2.0    5
# a    1.0      NaN   NaN         2.0    6
# d    7.0      NaN   NaN         8.0    8
# c    4.0      NaN   NaN         5.0    6
# g    NaN      NaN   NaN         NaN    8

# %%
frame4+frame2
# Out:
#    California  NewYork  Texas  Utah  std
# f         NaN      NaN    NaN   NaN  NaN
# b         4.0     12.0   12.0   8.0  NaN
# a         4.0      NaN    2.0   NaN  NaN
# d        16.0      NaN   14.0   NaN  NaN
# c        10.0      NaN    8.0   NaN  NaN
# g         NaN      NaN    NaN   NaN  NaN

# %%
frame2.loc['a':'d':-1]
# Out:
# Empty DataFrame
# Columns: [Texas, NewYork, Utah, California]
# Index: []

# %%
frame2.loc[::-1]
# Out:
#    Texas  NewYork  Utah  California
# g    NaN      NaN   NaN         NaN
# c    4.0      NaN   NaN         5.0
# d    7.0      NaN   NaN         8.0
# a    1.0      NaN   NaN         2.0
# b    6.0      6.0   4.0         2.0
# f    NaN      NaN   NaN         NaN

# %%
frame2.loc[::-1,'Texas'::-1]
# Out:
#    Texas
# g    NaN
# c    4.0
# d    7.0
# a    1.0
# b    6.0
# f    NaN

# %%
frame2.loc[::-1,::-1]
# Out:
#    California  Utah  NewYork  Texas
# g         NaN   NaN      NaN    NaN
# c         5.0   NaN      NaN    4.0
# d         8.0   NaN      NaN    7.0
# a         2.0   NaN      NaN    1.0
# b         2.0   4.0      6.0    6.0
# f         NaN   NaN      NaN    NaN

# %%
del frame2[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\python practice\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-0975de132d90> in <module>
# ----> 1 del frame2[0]
#
# ...

# %%
frame4[frame4>5]
# Out:
#    Texas  NewYork  Utah  California  std
# f    NaN      NaN   NaN         NaN  NaN
# b    6.0      6.0   NaN         NaN  NaN
# a    NaN      NaN   NaN         NaN  6.0
# d    7.0      NaN   NaN         8.0  8.0
# c    NaN      NaN   NaN         NaN  6.0
# g    NaN      NaN   NaN         NaN  8.0

# %%
frame4[frame4.isna()]
# Out:
#    Texas  NewYork  Utah  California  std
# f    NaN      NaN   NaN         NaN  NaN
# b    NaN      NaN   NaN         NaN  NaN
# a    NaN      NaN   NaN         NaN  NaN
# d    NaN      NaN   NaN         NaN  NaN
# c    NaN      NaN   NaN         NaN  NaN
# g    NaN      NaN   NaN         NaN  NaN

# %%
frame4.fillna(0)
frame4
# Out:
#    Texas  NewYork  Utah  California  std
# f    NaN      NaN   NaN         NaN    4
# b    6.0      6.0   4.0         2.0    5
# a    1.0      NaN   NaN         2.0    6
# d    7.0      NaN   NaN         8.0    8
# c    4.0      NaN   NaN         5.0    6
# g    NaN      NaN   NaN         NaN    8

# %%
frame4.fillna(0,inplace=True)

# %%
frame4
# Out:
#    Texas  NewYork  Utah  California  std
# f    0.0      0.0   0.0         0.0    4
# b    6.0      6.0   4.0         2.0    5
# a    1.0      0.0   0.0         2.0    6
# d    7.0      0.0   0.0         8.0    8
# c    4.0      0.0   0.0         5.0    6
# g    0.0      0.0   0.0         0.0    8

# %%
csvdata=pd.read_csv('data.csv.csv')
csvdata.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
df=csvdata

# %%
df[df['Best of Quizzes']>7]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# 19  022-14-110222  BS(CS)                 Mohammad Hunain   27     9.0
# 21  022-14-110593  BS(CS)  Muhammad Abdul Rehman Siddiqui   20     9.0
# 25  022-14-110105  BS(CS)                  Muhammad Faraz   26     9.0
# ...

# %%
df[df['Quiz 1']>7 and df['Quiz 2']>7].count
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-d3fb1e425730> in <module>
# ----> 1 df[df['Quiz 1']>7 and df['Quiz 2']>7].count
#
# D:\python practice\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
